# %% [markdown]
# Eval ispired by https://github.com/SiatMMLab/Awesome-Diffusion-Model-Based-Image-Editing-Methods/blob/main/EditEval_v1/Metric/LMM_Score_GPT4V_Prompt_Template.md

# %%
import base64
from openai import OpenAI
import os
import json 
import yaml

client = OpenAI()

# %%
def encode_image(path):
    with open(path, "rb") as f:
        return base64.b64encode(f.read()).decode("utf-8")


# ---------------------------
# Load images
# ---------------------------
def load_images(folder):
    source = encode_image(os.path.join(folder, "A.png"))
    edited = sorted([
        f for f in os.listdir(folder)
        if f.startswith("C")
        if len(f.split('unet')) < 3
    ])
    edited_imgs = [encode_image(os.path.join(folder, e)) for e in edited]
    layers_images = [e.replace('C_skips_','').replace('.png', '') for e in edited]
    return source, edited_imgs, layers_images

# --------------------------
# Helper: encode local image
# --------------------------

def build_content(TASK, INSTRUCTION, source_img, edited_imgs, layers):
  
    # --------------------------------------------
    # Build the full conversation up to scoring
    # --------------------------------------------
    messages = [
        {
            "role": "user",
            "content": (
                "I invite you to participate in an experiment on "
                "\"Evaluation of Image Editing Performance with Different Methods\". "
                "Are you ready?"
            )
        },
        {
            "role": "assistant",
            "content": "I'm ready and intrigued! Let's begin."
        },
        {
            "role": "user",
            "content": [
                "Step 1: Here is the source image, task indicator, and editing instruction.",
                {
                    "type": "image_url",
                    "image_url": {"url": f"data:image/jpeg;base64,{source_img}"}
                },
                f"Task indicator: {TASK}.",
                f"Instruction: {INSTRUCTION}.",
                "Please describe the source image and describe the editing process."
            ],
        },
    ]
    
    # --------------------------------------------
    # Add Step 2 instructions
    # --------------------------------------------
    messages.append({
        "role": "user",
        "content": (
            f"Step 2: Now I will upload {len(layers)} edited images. "
            "For each: give detailed analysis on 4 factors. The scores are from 0 to 10. "
            "(Editing Accuracy, Contextual Preservation, Visual Quality, Logical Realism). "
            """
            1. Editing Accuracy: Evaluate how closely the edited image adheres to the specified editing instruction, measuring the precision of the editing. 

            2. Contextual Preservation: Assess how well the edited image maintains the context of the source image that should not be changed. 
            
            3. Visual Quality: Assess the overall visual quality of the edited image. 
            
            4. Logical Realism: Evaluate how logically realistic the edited image is in terms of adherence to natural physical laws. 
            
            """
            "Do NOT score yet. After all images, I will ask for scores."
        )
    })
    
    # Add each edited image as a separate conversational turn
    for i, img in enumerate(edited_imgs):
        messages.append({
            "role": "user",
            "content": [
                f"Edited image {layers[i]}:",
                {"type": "image_url", "image_url": {"url": f"data:image/png;base64,{img}"}}
            ]
        })
    
    # --------------------------------------------
    # Step 3: Ask for scoring including S_all calc
    # --------------------------------------------
    messages.append({
        "role": "user",
        "content": (
            f"Now score all {len(layers)} images with four sub-scores (S_acc, S_pre, S_qua, S_real). "
            "Avoid identical scores. Then compute S_all = "
            "0.4*S_acc + 0.3*S_pre + 0.2*S_qua + 0.1*S_real for each."
            "You absolutely must return the results as a json containing the layer names as keys, and the subkeys being the metrics with values the scores."
        )
    })
    return messages


def extract_json_from_text(text: str):
    """
    Extracts JSON enclosed in ```json ... ``` from a long string and returns parsed Python object.
    """

    # Regex to extract JSON inside triple backticks
    start = text.find("{")
    if start == -1:
        raise ValueError("No '{' found in text")

    brace_count = 0
    inside = False

    for i in range(start, len(text)):
        if text[i] == "{":
            brace_count += 1
            inside = True
        elif text[i] == "}":
            brace_count -= 1
            if brace_count == 0 and inside:
                return text[start:i+1]

    # ---- 3. Clean trailing commas before } or ] ----
    block = re.sub(r",\s*([}\]])", r"\1", text)

    # ---- 4. Load JSON safely ----
    try:
        return json.loads(block)
    except json.JSONDecodeError as e:
        print("FAILED BLOCK:\n", block)
        raise e

# %%
from glob import glob
from PIL import Image
import re

FOLDER = "../outputs_per_model/outputs_sd-turbo_controlled"
folders = glob(FOLDER + '/*')[:4]
print(len(folders))
TASK = "Object and Style Change"

OUT_FOLDER = 'output_scores'

for FOLDER in folders:
    source, edits, layers = load_images(FOLDER)
    _, prompt_a, prompt_b = FOLDER.split('/')[-1].split('A_high-resolution_image_of_a_')

    INSTRUCTION = f"Change an image described by {prompt_a.replace('_',' ')}to an image containing {prompt_b.replace('_',' ')}"
    print(INSTRUCTION)

    messages = build_content(TASK, INSTRUCTION, source, edits, layers)

    # --------------------------------------------
    # Call the API (choose a model)
    # --------------------------------------------
    response = client.chat.completions.create(
        model="gpt-5-mini-2025-08-07",   # or "gpt-4.1-mini", "gpt-4o-mini", "gpt-4.1-vision"
        messages=messages,
    )
    output = response.choices[0].message.content
    #print(output)
        
    scores = extract_json_from_text(output)
    scores = eval(scores)
    for keys, score in scores.items():
        scores[keys]["folder"] = FOLDER
        scores[keys]['A'] = prompt_a
        scores[keys]['B'] = prompt_b     
    
    #print(scores)
    
    os.makedirs(os.path.join(OUT_FOLDER, FOLDER), exist_ok=True)

    with open(os.path.join(OUT_FOLDER, FOLDER, "results.json"), "w") as f:
        json.dump(scores, f, indent=2)
    

print("\n✅ All scores saved to results.json")
# Out:
# 26
# Change an image described by glass perfume bottle in the outer space asteroid base, HDR hyperrealism to an image containing steampunk airship in the Nordic fjord cliffs, pastel kawaii style
# Change an image described by futuristic motorbike in the tropical beach, surreal dreamlike style to an image containing zebra in the mountains, claymation style
# Change an image described by candle lantern in the cloud kingdom above the earth, glitch effect aesthetic to an image containing glass chess set in the outer space asteroid base, Art Nouveau illustration
# Change an image described by robot assistant in the library with infinite shelves, storybook illustration to an image containing parrot in the desert, luxury fashion editorial style
# Change an image described by dragon figurine in the futuristic skyline, origami paper craft style to an image containing space rover in the stormy ocean cliffs, 3D Pixar-style rendering
# Change an image described by elephant in the volcanic landscape, oil painting renaissance style to an image containing katana sword in the old european village, Art Nouveau illustration
# Change an image described by ancient book of spells in the haunted Victorian mansion, storybook illustration to an image containing fountain pen in the Victorian London streets, luxury fashion editorial style
# Change an image described by lunar telescope in the tropical beach, japanese anime style to an image containing retro arcade machine in the lush waterfall canyon, HDR hyperrealism
# Change an image described by smartphone hologram in the robot factory assembly line, stained glass style to an image containing zebra in the hidden bamboo grove, retro futurism style
# Change an image described by pirate treasure chest in the abandoned amusement park, claymation style to an image containing casette player in the medieval castle courtyard, 3D Pixar-style rendering
# Change an image described by retro arcade machine in the desert, futuristic hologram style to an image containing casette player in the coral reef underwater world, baroque painting style
# Change an image described by parrot in the floating sky islands, comic manga speedline style to an image containing smartphone hologram in the submerged ancient city, glitch effect aesthetic
# Change an image described by robot assistant in the marble palace interior, children’s book pastel style to an image containing old typewriter in the medieval castle courtyard, low-poly 3D style
# Change an image described by ballet shoes in the forest, charcoal sketch to an image containing astronaut helmet in the coral reef underwater world, AI-generated abstract fractal style
# Change an image described by steampunk airship in the fantasy dwarven mine, biomechanical art to an image containing smartphone hologram in the forest, neoclassical sculpture style
# Change an image described by ancient compass in the stormy ocean cliffs, retro 80s synthwave to an image containing samurai helmet in the futuristic biotech lab, 3D Pixar-style rendering
# Change an image described by skateboard in the city, pastel kawaii style to an image containing steampunk airship in the enchanted magic forest, children’s book pastel style
# Change an image described by katana sword in the futuristic biotech lab, photorealistic studio lighting to an image containing ceramic teapot in the ancient Greek temple, retro 80s synthwave
# Change an image described by glass perfume bottle in the floating sky islands, blueprint technical style to an image containing cybernetic arm in the stormy ocean cliffs, futuristic hologram style
# Change an image described by vintage camera in the medieval castle courtyard, neoclassical sculpture style to an image containing astronaut helmet in the city, vaporwave aesthetic
# Change an image described by glass perfume bottle in the Nordic fjord cliffs, origami paper craft style to an image containing ballet shoes in the forest, abstract expressionism
# Change an image described by parrot in the city, black and white to an image containing wooden toy train in the floating sky islands, origami paper craft style
# Change an image described by parrot in the Aztec jungle temple, Art Nouveau illustration to an image containing gold pocket watch in the coral reef underwater world, low-poly 3D style
# Change an image described by elephant in the steampunk industrial city, liquid metal reflective style to an image containing pirate treasure chest in the savanna, pixel art style
